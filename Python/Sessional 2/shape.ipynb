# %%
from mysql.connector import Connect,Error
class Shape:
    def calcArea(self):
        pass
    
    def calcPerimeter(self):
        pass
    
    def save():
        pass
##

class Circle(Shape):
    def __init__(self,r):
        self.radius = r
    
    def save(self):
        con = Connect(
            host="localhost",
            port = 3307,
            user = "root",
            password ="Appu_2003",
            database = "pydb"
        )
        
        cursor = con.cursor()
        
        sql = "INSERT INTO shape(name,area,perimeter) VALUES(%s,%s,%s)"
        values =('Circle',self.area,self.peri)
        cursor.execute(sql,values)
        con.commit()
        print("Circle Data Inserted Into database")        
    
    def calcArea(self):
        self.area = 3.14 * self.radius *self.radius
        print("Area : ",self.area)

    def calcPerimeter(self):
        self.peri = 2*3.14*self.radius
        print("Circumference : ",self.peri)
        
##

class Square(Shape):
    def __init__(self,l):
        self.length = l
    
    def save(self):
        con = Connect(
            host="localhost",
            port = 3307,
            user = "root",
            password ="Appu_2003",
            database = "pydb"
        )
        
        cursor = con.cursor()
        
        sql = "INSERT INTO shape(name,area,perimeter) VALUES(%s,%s,%s)"
        values =('Square',self.area,self.peri)
        cursor.execute(sql,values)
        con.commit()
        print("Square Data Inserted Into database")        
    
    def calcArea(self):
        self.area = self.length*self.length
        print("Area : ",self.area)

    def calcPerimeter(self):
        self.peri = 4*self.length
        print("Perimeter : ",self.peri)
        
##


# Objects of circle class
# c_obj = Circle(5)
# c_obj.calcArea()
# c_obj.calcPerimeter()
# c_obj.save()

# Square
s_obj = Square(10)
s_obj.calcArea()
s_obj.calcPerimeter()
s_obj.save()
# Out:
# Area :  100
# Perimeter :  40
# Square Data Inserted Into database
